# %%
import pickle

# %%
X = pickle.load(open('X.pkl', 'rb'))
y = pickle.load(open('y.pkl', 'rb'))

# %%
X
# Out:
# array([[[[  1,  11,  35],
#          [  1,  12,  34],
#          [  0,  10,  30],
#          ...,
#          [ 77,  69,  56],
#          [ 76,  68,  55],
#          [ 75,  67,  54]],
#
#         [[  1,  11,  35],
#          [  1,  12,  34],
#          [  1,  12,  32],
#          ...,
#          [ 77,  69,  56],
#          [ 76,  68,  55],
#          [ 75,  67,  54]],
#
#         [[  2,  12,  36],
#          [  2,  13,  35],
#          [  1,  12,  32],
#          ...,
#          [ 77,  69,  56],
#          [ 77,  69,  56],
#          [ 77,  69,  56]],
#
#         ...,
#
#         [[  1,   7,  42],
#          [  1,   7,  42],
#          [  2,   8,  43],
#          ...,
#          [  2,  21,  54],
#          [ 12,  29,  62],
#          [  0,  15,  48]],
#
#         [[ 10,  16,  51],
#          [  5,  11,  46],
#          [  5,  11,  46],
#          ...,
#          [  4,  22,  51],
#          [  6,  22,  51],
#          [  4,  20,  49]],
#
#         [[  0,  13,  49],
#          [  4,  10,  45],
#          [  1,   4,  35],
#          ...,
#          [  2,  19,  52],
#          [  5,  23,  54],
#          [  4,  22,  53]]],
#
#
#        [[[162, 174, 176],
#          [148, 160, 164],
#          [140, 151, 158],
#          ...,
#          [ 40,  47,  72],
#          [ 42,  47,  72],
#          [ 47,  49,  75]],
#
#         [[109, 135, 141],
#          [ 57,  83,  90],
#          [ 60,  84,  94],
#          ...,
#          [ 42,  47,  72],
#          [ 46,  50,  75],
#          [ 47,  47,  73]],
#
#         [[ 83, 106, 117],
#          [100, 122, 134],
#          [105, 125, 142],
#          ...,
#          [ 42,  46,  71],
#          [ 45,  46,  72],
#          [ 47,  46,  72]],
#
#         ...,
#
#         [[ 47,  76, 106],
#          [ 72, 104, 125],
#          [ 56,  96, 104],
#          ...,
#          [248, 245, 251],
#          [239, 239, 245],
#          [245, 248, 254]],
#
#         [[ 41,  78, 103],
#          [ 56,  96, 115],
#          [ 74, 117, 127],
#          ...,
#          [247, 249, 252],
#          [238, 241, 244],
#          [243, 249, 251]],
#
#         [[ 66, 109, 130],
#          [ 65, 110, 124],
#          [ 50,  98, 104],
#          ...,
#          [247, 250, 251],
#          [236, 241, 242],
#          [240, 248, 248]]],
#
#
#        [[[163, 196, 195],
#          [140, 168, 165],
#          [177, 195, 196],
#          ...,
#          [ 81, 119, 124],
#          [ 89, 127, 132],
#          [100, 136, 142]],
#
#         [[158, 171, 163],
#          [188, 196, 189],
#          [199, 202, 196],
#          ...,
#          [103, 132, 141],
#          [109, 138, 146],
#          [110, 139, 142]],
#
#         [[139, 146, 140],
#          [128, 137, 130],
#          [146, 155, 148],
#          ...,
#          [164, 172, 174],
#          [163, 170, 173],
#          [160, 165, 164]],
#
#         ...,
#
#         [[ 69,  91, 105],
#          [ 58,  85,  99],
#          [ 63,  90, 103],
#          ...,
#          [106, 130, 127],
#          [116, 136, 134],
#          [116, 127, 124]],
#
#         [[ 46,  74,  91],
#          [ 41,  69,  76],
#          [ 58,  80,  91],
#          ...,
#          [185, 193, 193],
#          [156, 169, 169],
#          [117, 131, 131]],
#
#         [[ 64,  93, 110],
#          [ 52,  80,  87],
#          [ 81, 103, 114],
#          ...,
#          [102, 111, 114],
#          [123, 133, 136],
#          [103, 113, 113]]],
#
#
#        ...,
#
#
#        [[[117, 138, 125],
#          [116, 151, 127],
#          [106, 149, 120],
#          ...,
#          [116, 144, 121],
#          [118, 144, 125],
#          [117, 144, 118]],
#
#         [[101, 134, 108],
#          [ 70, 118,  81],
#          [ 78, 134,  93],
#          ...,
#          [130, 152, 123],
#          [117, 138, 114],
#          [125, 150, 130]],
#
#         [[137, 153, 132],
#          [121, 151, 120],
#          [118, 156, 120],
#          ...,
#          [121, 150, 124],
#          [121, 146, 126],
#          [122, 148, 123]],
#
#         ...,
#
#         [[106, 110, 103],
#          [ 95, 104,  90],
#          [ 87,  93,  83],
#          ...,
#          [100, 107,  91],
#          [104, 117,  91],
#          [ 77, 100,  69]],
#
#         [[119, 136, 123],
#          [115, 148, 132],
#          [ 78, 113,  99],
#          ...,
#          [ 71,  96,  69],
#          [ 74, 105,  74],
#          [ 65, 105,  76]],
#
#         [[ 67,  76,  69],
#          [ 42,  61,  49],
#          [ 81,  92,  76],
#          ...,
#          [132, 161, 131],
#          [ 96, 132,  97],
#          [ 77, 108,  77]]],
#
#
#        [[[251, 251, 251],
#          [253, 253, 253],
#          [255, 255, 255],
#          ...,
#          [238, 238, 238],
#          [255, 255, 255],
#          [254, 254, 254]],
#
#         [[252, 252, 252],
#          [248, 248, 248],
#          [254, 254, 254],
#          ...,
#          [245, 245, 245],
#          [253, 253, 253],
#          [250, 250, 250]],
#
#         [[255, 255, 255],
#          [249, 249, 249],
#          [255, 255, 255],
#          ...,
#          [252, 252, 252],
#          [250, 250, 250],
#          [254, 254, 254]],
#
#         ...,
#
#         [[223, 242, 250],
#          [203, 232, 239],
#          [224, 241, 248],
#          ...,
#          [200, 196, 188],
#          [199, 196, 189],
#          [208, 205, 200]],
#
#         [[200, 226, 242],
#          [189, 224, 238],
#          [204, 229, 244],
#          ...,
#          [191, 194, 185],
#          [212, 218, 208],
#          [187, 192, 183]],
#
#         [[192, 220, 227],
#          [185, 214, 229],
#          [178, 208, 225],
#          ...,
#          [193, 200, 195],
#          [222, 222, 218],
#          [201, 198, 194]]],
#
#
#        [[[248, 252, 252],
#          [242, 242, 242],
#          [252, 252, 252],
#          ...,
#          [246, 250, 250],
#          [249, 255, 254],
#          [247, 255, 254]],
#
#         [[242, 244, 244],
#          [248, 250, 250],
#          [217, 220, 220],
#          ...,
#          [246, 252, 251],
#          [252, 254, 254],
#          [254, 254, 254]],
#
#         [[245, 250, 249],
#          [239, 249, 248],
#          [230, 243, 241],
#          ...,
#          [242, 249, 248],
#          [254, 254, 254],
#          [255, 252, 253]],
#
#         ...,
#
#         [[ 67,  95,  96],
#          [ 83, 118, 108],
#          [ 44,  93,  71],
#          ...,
#          [ 46, 111,  82],
#          [ 57, 141, 112],
#          [ 86, 147, 134]],
#
#         [[ 51,  93,  82],
#          [ 35,  76,  61],
#          [ 54,  99,  80],
#          ...,
#          [ 19,  87,  59],
#          [ 27, 111,  81],
#          [ 49, 113,  94]],
#
#         [[ 26,  81,  68],
#          [ 32,  83,  66],
#          [ 56, 101,  82],
#          ...,
#          [ 21,  86,  56],
#          [ 26,  97,  66],
#          [ 11,  63,  44]]]], dtype=uint8)

# %%
y
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
X = X/255

# %%
X
# Out:
# array([[[[0.00392157, 0.04313725, 0.1372549 ],
#          [0.00392157, 0.04705882, 0.13333333],
#          [0.        , 0.03921569, 0.11764706],
#          ...,
#          [0.30196078, 0.27058824, 0.21960784],
#          [0.29803922, 0.26666667, 0.21568627],
#          [0.29411765, 0.2627451 , 0.21176471]],
#
#         [[0.00392157, 0.04313725, 0.1372549 ],
#          [0.00392157, 0.04705882, 0.13333333],
#          [0.00392157, 0.04705882, 0.1254902 ],
#          ...,
#          [0.30196078, 0.27058824, 0.21960784],
#          [0.29803922, 0.26666667, 0.21568627],
#          [0.29411765, 0.2627451 , 0.21176471]],
#
#         [[0.00784314, 0.04705882, 0.14117647],
#          [0.00784314, 0.05098039, 0.1372549 ],
#          [0.00392157, 0.04705882, 0.1254902 ],
#          ...,
#          [0.30196078, 0.27058824, 0.21960784],
#          [0.30196078, 0.27058824, 0.21960784],
#          [0.30196078, 0.27058824, 0.21960784]],
#
#         ...,
#
#         [[0.00392157, 0.02745098, 0.16470588],
#          [0.00392157, 0.02745098, 0.16470588],
#          [0.00784314, 0.03137255, 0.16862745],
#          ...,
#          [0.00784314, 0.08235294, 0.21176471],
#          [0.04705882, 0.11372549, 0.24313725],
#          [0.        , 0.05882353, 0.18823529]],
#
#         [[0.03921569, 0.0627451 , 0.2       ],
#          [0.01960784, 0.04313725, 0.18039216],
#          [0.01960784, 0.04313725, 0.18039216],
#          ...,
#          [0.01568627, 0.08627451, 0.2       ],
#          [0.02352941, 0.08627451, 0.2       ],
#          [0.01568627, 0.07843137, 0.19215686]],
#
#         [[0.        , 0.05098039, 0.19215686],
#          [0.01568627, 0.03921569, 0.17647059],
#          [0.00392157, 0.01568627, 0.1372549 ],
#          ...,
#          [0.00784314, 0.0745098 , 0.20392157],
#          [0.01960784, 0.09019608, 0.21176471],
#          [0.01568627, 0.08627451, 0.20784314]]],
#
#
#        [[[0.63529412, 0.68235294, 0.69019608],
#          [0.58039216, 0.62745098, 0.64313725],
#          [0.54901961, 0.59215686, 0.61960784],
#          ...,
#          [0.15686275, 0.18431373, 0.28235294],
#          [0.16470588, 0.18431373, 0.28235294],
#          [0.18431373, 0.19215686, 0.29411765]],
#
#         [[0.42745098, 0.52941176, 0.55294118],
#          [0.22352941, 0.3254902 , 0.35294118],
#          [0.23529412, 0.32941176, 0.36862745],
#          ...,
#          [0.16470588, 0.18431373, 0.28235294],
#          [0.18039216, 0.19607843, 0.29411765],
#          [0.18431373, 0.18431373, 0.28627451]],
#
#         [[0.3254902 , 0.41568627, 0.45882353],
#          [0.39215686, 0.47843137, 0.5254902 ],
#          [0.41176471, 0.49019608, 0.55686275],
#          ...,
#          [0.16470588, 0.18039216, 0.27843137],
#          [0.17647059, 0.18039216, 0.28235294],
#          [0.18431373, 0.18039216, 0.28235294]],
#
#         ...,
#
#         [[0.18431373, 0.29803922, 0.41568627],
#          [0.28235294, 0.40784314, 0.49019608],
#          [0.21960784, 0.37647059, 0.40784314],
#          ...,
#          [0.97254902, 0.96078431, 0.98431373],
#          [0.9372549 , 0.9372549 , 0.96078431],
#          [0.96078431, 0.97254902, 0.99607843]],
#
#         [[0.16078431, 0.30588235, 0.40392157],
#          [0.21960784, 0.37647059, 0.45098039],
#          [0.29019608, 0.45882353, 0.49803922],
#          ...,
#          [0.96862745, 0.97647059, 0.98823529],
#          [0.93333333, 0.94509804, 0.95686275],
#          [0.95294118, 0.97647059, 0.98431373]],
#
#         [[0.25882353, 0.42745098, 0.50980392],
#          [0.25490196, 0.43137255, 0.48627451],
#          [0.19607843, 0.38431373, 0.40784314],
#          ...,
#          [0.96862745, 0.98039216, 0.98431373],
#          [0.9254902 , 0.94509804, 0.94901961],
#          [0.94117647, 0.97254902, 0.97254902]]],
#
#
#        [[[0.63921569, 0.76862745, 0.76470588],
#          [0.54901961, 0.65882353, 0.64705882],
#          [0.69411765, 0.76470588, 0.76862745],
#          ...,
#          [0.31764706, 0.46666667, 0.48627451],
#          [0.34901961, 0.49803922, 0.51764706],
#          [0.39215686, 0.53333333, 0.55686275]],
#
#         [[0.61960784, 0.67058824, 0.63921569],
#          [0.7372549 , 0.76862745, 0.74117647],
#          [0.78039216, 0.79215686, 0.76862745],
#          ...,
#          [0.40392157, 0.51764706, 0.55294118],
#          [0.42745098, 0.54117647, 0.57254902],
#          [0.43137255, 0.54509804, 0.55686275]],
#
#         [[0.54509804, 0.57254902, 0.54901961],
#          [0.50196078, 0.5372549 , 0.50980392],
#          [0.57254902, 0.60784314, 0.58039216],
#          ...,
#          [0.64313725, 0.6745098 , 0.68235294],
#          [0.63921569, 0.66666667, 0.67843137],
#          [0.62745098, 0.64705882, 0.64313725]],
#
#         ...,
#
#         [[0.27058824, 0.35686275, 0.41176471],
#          [0.22745098, 0.33333333, 0.38823529],
#          [0.24705882, 0.35294118, 0.40392157],
#          ...,
#          [0.41568627, 0.50980392, 0.49803922],
#          [0.45490196, 0.53333333, 0.5254902 ],
#          [0.45490196, 0.49803922, 0.48627451]],
#
#         [[0.18039216, 0.29019608, 0.35686275],
#          [0.16078431, 0.27058824, 0.29803922],
#          [0.22745098, 0.31372549, 0.35686275],
#          ...,
#          [0.7254902 , 0.75686275, 0.75686275],
#          [0.61176471, 0.6627451 , 0.6627451 ],
#          [0.45882353, 0.51372549, 0.51372549]],
#
#         [[0.25098039, 0.36470588, 0.43137255],
#          [0.20392157, 0.31372549, 0.34117647],
#          [0.31764706, 0.40392157, 0.44705882],
#          ...,
#          [0.4       , 0.43529412, 0.44705882],
#          [0.48235294, 0.52156863, 0.53333333],
#          [0.40392157, 0.44313725, 0.44313725]]],
#
#
#        ...,
#
#
#        [[[0.45882353, 0.54117647, 0.49019608],
#          [0.45490196, 0.59215686, 0.49803922],
#          [0.41568627, 0.58431373, 0.47058824],
#          ...,
#          [0.45490196, 0.56470588, 0.4745098 ],
#          [0.4627451 , 0.56470588, 0.49019608],
#          [0.45882353, 0.56470588, 0.4627451 ]],
#
#         [[0.39607843, 0.5254902 , 0.42352941],
#          [0.2745098 , 0.4627451 , 0.31764706],
#          [0.30588235, 0.5254902 , 0.36470588],
#          ...,
#          [0.50980392, 0.59607843, 0.48235294],
#          [0.45882353, 0.54117647, 0.44705882],
#          [0.49019608, 0.58823529, 0.50980392]],
#
#         [[0.5372549 , 0.6       , 0.51764706],
#          [0.4745098 , 0.59215686, 0.47058824],
#          [0.4627451 , 0.61176471, 0.47058824],
#          ...,
#          [0.4745098 , 0.58823529, 0.48627451],
#          [0.4745098 , 0.57254902, 0.49411765],
#          [0.47843137, 0.58039216, 0.48235294]],
#
#         ...,
#
#         [[0.41568627, 0.43137255, 0.40392157],
#          [0.37254902, 0.40784314, 0.35294118],
#          [0.34117647, 0.36470588, 0.3254902 ],
#          ...,
#          [0.39215686, 0.41960784, 0.35686275],
#          [0.40784314, 0.45882353, 0.35686275],
#          [0.30196078, 0.39215686, 0.27058824]],
#
#         [[0.46666667, 0.53333333, 0.48235294],
#          [0.45098039, 0.58039216, 0.51764706],
#          [0.30588235, 0.44313725, 0.38823529],
#          ...,
#          [0.27843137, 0.37647059, 0.27058824],
#          [0.29019608, 0.41176471, 0.29019608],
#          [0.25490196, 0.41176471, 0.29803922]],
#
#         [[0.2627451 , 0.29803922, 0.27058824],
#          [0.16470588, 0.23921569, 0.19215686],
#          [0.31764706, 0.36078431, 0.29803922],
#          ...,
#          [0.51764706, 0.63137255, 0.51372549],
#          [0.37647059, 0.51764706, 0.38039216],
#          [0.30196078, 0.42352941, 0.30196078]]],
#
#
#        [[[0.98431373, 0.98431373, 0.98431373],
#          [0.99215686, 0.99215686, 0.99215686],
#          [1.        , 1.        , 1.        ],
#          ...,
#          [0.93333333, 0.93333333, 0.93333333],
#          [1.        , 1.        , 1.        ],
#          [0.99607843, 0.99607843, 0.99607843]],
#
#         [[0.98823529, 0.98823529, 0.98823529],
#          [0.97254902, 0.97254902, 0.97254902],
#          [0.99607843, 0.99607843, 0.99607843],
#          ...,
#          [0.96078431, 0.96078431, 0.96078431],
#          [0.99215686, 0.99215686, 0.99215686],
#          [0.98039216, 0.98039216, 0.98039216]],
#
#         [[1.        , 1.        , 1.        ],
#          [0.97647059, 0.97647059, 0.97647059],
#          [1.        , 1.        , 1.        ],
#          ...,
#          [0.98823529, 0.98823529, 0.98823529],
#          [0.98039216, 0.98039216, 0.98039216],
#          [0.99607843, 0.99607843, 0.99607843]],
#
#         ...,
#
#         [[0.8745098 , 0.94901961, 0.98039216],
#          [0.79607843, 0.90980392, 0.9372549 ],
#          [0.87843137, 0.94509804, 0.97254902],
#          ...,
#          [0.78431373, 0.76862745, 0.7372549 ],
#          [0.78039216, 0.76862745, 0.74117647],
#          [0.81568627, 0.80392157, 0.78431373]],
#
#         [[0.78431373, 0.88627451, 0.94901961],
#          [0.74117647, 0.87843137, 0.93333333],
#          [0.8       , 0.89803922, 0.95686275],
#          ...,
#          [0.74901961, 0.76078431, 0.7254902 ],
#          [0.83137255, 0.85490196, 0.81568627],
#          [0.73333333, 0.75294118, 0.71764706]],
#
#         [[0.75294118, 0.8627451 , 0.89019608],
#          [0.7254902 , 0.83921569, 0.89803922],
#          [0.69803922, 0.81568627, 0.88235294],
#          ...,
#          [0.75686275, 0.78431373, 0.76470588],
#          [0.87058824, 0.87058824, 0.85490196],
#          [0.78823529, 0.77647059, 0.76078431]]],
#
#
#        [[[0.97254902, 0.98823529, 0.98823529],
#          [0.94901961, 0.94901961, 0.94901961],
#          [0.98823529, 0.98823529, 0.98823529],
#          ...,
#          [0.96470588, 0.98039216, 0.98039216],
#          [0.97647059, 1.        , 0.99607843],
#          [0.96862745, 1.        , 0.99607843]],
#
#         [[0.94901961, 0.95686275, 0.95686275],
#          [0.97254902, 0.98039216, 0.98039216],
#          [0.85098039, 0.8627451 , 0.8627451 ],
#          ...,
#          [0.96470588, 0.98823529, 0.98431373],
#          [0.98823529, 0.99607843, 0.99607843],
#          [0.99607843, 0.99607843, 0.99607843]],
#
#         [[0.96078431, 0.98039216, 0.97647059],
#          [0.9372549 , 0.97647059, 0.97254902],
#          [0.90196078, 0.95294118, 0.94509804],
#          ...,
#          [0.94901961, 0.97647059, 0.97254902],
#          [0.99607843, 0.99607843, 0.99607843],
#          [1.        , 0.98823529, 0.99215686]],
#
#         ...,
#
#         [[0.2627451 , 0.37254902, 0.37647059],
#          [0.3254902 , 0.4627451 , 0.42352941],
#          [0.17254902, 0.36470588, 0.27843137],
#          ...,
#          [0.18039216, 0.43529412, 0.32156863],
#          [0.22352941, 0.55294118, 0.43921569],
#          [0.3372549 , 0.57647059, 0.5254902 ]],
#
#         [[0.2       , 0.36470588, 0.32156863],
#          [0.1372549 , 0.29803922, 0.23921569],
#          [0.21176471, 0.38823529, 0.31372549],
#          ...,
#          [0.0745098 , 0.34117647, 0.23137255],
#          [0.10588235, 0.43529412, 0.31764706],
#          [0.19215686, 0.44313725, 0.36862745]],
#
#         [[0.10196078, 0.31764706, 0.26666667],
#          [0.1254902 , 0.3254902 , 0.25882353],
#          [0.21960784, 0.39607843, 0.32156863],
#          ...,
#          [0.08235294, 0.3372549 , 0.21960784],
#          [0.10196078, 0.38039216, 0.25882353],
#          [0.04313725, 0.24705882, 0.17254902]]]])

# %%
X.shape
# Out:
# (23000, 100, 100, 3)

# %%
X = X.reshape(-1, 60, 60, 1)

# %%
# !pip install keras Sequential activations tensorflow

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
# Out:
# 2024-04-30 15:25:46.495563: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model = Sequential()

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(128, input_shape = X.shape[1:], activation = 'relu'))

model.add(Dense(2, activation = 'softmax'))
# Out:
# /home/jkozik/projects/Cats-Vs-Dogs-Prediction/venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X, y, epochs=5, validation_split=0.1)
# Out:
# Epoch 1/5
# 2024-04-30 15:26:26.628484: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 2484000000 exceeds 10% of free system memory.
# 647/647 ━━━━━━━━━━━━━━━━━━━━ 542s 833ms/step - accuracy: 0.6012 - loss: 0.6766 - val_accuracy: 0.6583 - val_loss: 0.6577
# Epoch 2/5
# 647/647 ━━━━━━━━━━━━━━━━━━━━ 556s 824ms/step - accuracy: 0.7217 - loss: 0.5523 - val_accuracy: 0.7526 - val_loss: 0.5028
# Epoch 3/5
# 647/647 ━━━━━━━━━━━━━━━━━━━━ 555s 813ms/step - accuracy: 0.7993 - loss: 0.4289 - val_accuracy: 0.7778 - val_loss: 0.4724
# Epoch 4/5
# 647/647 ━━━━━━━━━━━━━━━━━━━━ 561s 812ms/step - accuracy: 0.8525 - loss: 0.3300 - val_accuracy: 0.7757 - val_loss: 0.5085
# Epoch 5/5
# 647/647 ━━━━━━━━━━━━━━━━━━━━ 559s 807ms/step - accuracy: 0.9286 - loss: 0.1829 - val_accuracy: 0.7657 - val_loss: 0.6538

# %%
X.shape

# %%
import time

time.time()

# %%
type(1581428129.5990093)
